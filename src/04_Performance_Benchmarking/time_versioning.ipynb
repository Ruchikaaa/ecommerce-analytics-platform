# %% [markdown]
# ## View Table History

# %%
# %sql
DESCRIBE HISTORY ecommerce_analytics_dev.silver_layer.events_cleaned;

# %% [markdown]
# ## Time Travel Query

# %%
# %sql
SELECT * FROM ecommerce_analytics_dev.silver_layer.events_cleaned VERSION AS OF 17
LIMIT 5;
