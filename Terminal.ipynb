# %%
# %sql
-- Check the actual counts in the catalog
SELECT count(*) FROM ecommerce_analytics_dev.bronze_layer.events_raw;

# %%
# %sql
SELECT count(*) FROM ecommerce_analytics_dev.silver_layer.events_cleaned;
